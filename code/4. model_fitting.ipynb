# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.float_format = '{:,.2f}'.format

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from xgboost import XGBClassifier
import warnings

# %%
df_1 = pd.read_csv("../data/processed/df_final_1.csv", index_col=0)
df_2 = pd.read_csv("../data/processed/df_final_2.csv", index_col=0)
df_3 = pd.read_csv("../data/processed/df_final_3.csv", index_col=0)
df_4 = pd.read_csv("../data/processed/df_final_4.csv", index_col=0)

# %%
# random forest
def pred_eval(df, model):
    X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,2:], df.iloc[:,0], test_size=0.2, random_state=0)
    model.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    f1 = f1_score(y_test, y_pred, average='micro')
    print(f"f1_score: {f1:.4f}")
    return model

# %%
clf = RandomForestClassifier()
pred_eval(df_1, clf)
clf = RandomForestClassifier()
pred_eval(df_2, clf)
clf = RandomForestClassifier()
pred_eval(df_3, clf)
clf = RandomForestClassifier()
pred_eval(df_4, clf)
# Out:
# f1_score: 0.2223
# f1_score: 0.2202
# f1_score: 0.2217
# f1_score: 0.2116
# RandomForestClassifier()

# %%
# gradiant boosting
clf = XGBClassifier(max_depth=3, learning_rate=0.01, n_estimators=100)
X_train, X_test, y_train, y_test = train_test_split(df_2.iloc[:,2:], df_2.iloc[:,0], test_size=0.2, random_state=0)
clf.fit(X_train, LabelEncoder().fit_transform(y_train))
y_pred = clf.predict(X_test)
print(f"f1_score: {f1_score(LabelEncoder().fit_transform(y_test), y_pred, average='micro'):.4f}")
# Out:
# f1_score: 0.2339

# %%
# naive bayes ...
